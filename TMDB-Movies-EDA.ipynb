# %%
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

# %%
# creat the dataframe
df=pd.read_csv('/content/movies.imbd.csv')

# %%
# display top 10 rows of the dataset
df.head(10)
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
# 5      5  258000000                  Fantasy Action Adventure
# 6      6  260000000                          Animation Family
# 7      7  280000000          Action Adventure Science Fiction
# 8      8  250000000                  Adventure Fantasy Family
# 9      9  250000000                  Action Adventure Fantasy
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
# check last 10 rows of the dataset
df.tail(10)
# Out:
#       index  budget                          genres  \
# 4793   4793       0                           Drama
# 4794   4794       0          Thriller Horror Comedy
# 4795   4795       0                           Drama
# 4796   4796    7000  Science Fiction Drama Thriller
# 4797   4797       0                Foreign Thriller
# 4798   4798  220000           Action Crime Thriller
# 4799   4799    9000                  Comedy Romance
# 4800   4800       0   Comedy Drama Romance TV Movie
# 4801   4801       0                             NaN
# 4802   4802       0                     Documentary
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# 4796                         http://www.primermovie.com   14337
# 4797                                                NaN   67238
# ...

# %%
# find shape of our dataset(number of rows and number of columns)
df.shape
# Out:
# (4803, 24)

# %%
print('number of rows',df.shape[0])
print('number of columns',df.shape[1])
# Out:
# number of rows 4803
# number of columns 24

# %%
# getting information about our dataset like total number rows,total number of columns,datatypes of each column and memory requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
# check missing values in the dataset
df.isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
print('any missing value?',df.isnull().values.any())
# Out:
# any missing value? True

# %%
df.isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
value_missing = df.isnull().sum()*100/len(df)
value_missing
# Out:
# index                    0.000000
# budget                   0.000000
# genres                   0.582969
# homepage                64.355611
# id                       0.000000
# keywords                 8.577972
# original_language        0.000000
# original_title           0.000000
# overview                 0.062461
# popularity               0.000000
# production_companies     0.000000
# production_countries     0.000000
# release_date             0.020820
# revenue                  0.000000
# runtime                  0.041641
# spoken_languages         0.000000
# status                   0.000000
# tagline                 17.572351
# title                    0.000000
# vote_average             0.000000
# vote_count               0.000000
# cast                     0.895274
# crew                     0.000000
# director                 0.624610
# year                     0.020820
# dtype: float64

# %%
# drop all missing values
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# index                   0
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# director                0
# year                    0
# dtype: int64

# %%
# check for duplicate data
dup_df = df.duplicated().any()

# %%
print('any duplicate values?',dup_df)
# Out:
# any duplicate values? False

# %%
df = df.drop_duplicates()
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4772   4772      31192                       Drama Action Comedy
# 4773   4773      27000                                    Comedy
# 4781   4781      22000                            Comedy Romance
# 4791   4791         13                                    Horror
# 4796   4796       7000            Science Fiction Drama Thriller
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
# get overall statistics about the dataframe
df.describe(include='all')
# Out:
#               index        budget genres                          homepage  \
# count   1432.000000  1.432000e+03   1432                              1432
# unique          NaN           NaN    535                              1412
# top             NaN           NaN  Drama  http://www.thehungergames.movie/
# freq            NaN           NaN     89                                 4
# mean    1885.148045  4.729039e+07    NaN                               NaN
# min        0.000000  0.000000e+00    NaN                               NaN
# 25%      648.250000  8.650000e+06    NaN                               NaN
# 50%     1654.500000  2.900000e+07    NaN                               NaN
# 75%     2979.250000  6.500000e+07    NaN                               NaN
# max     4796.000000  3.800000e+08    NaN                               NaN
# std     1388.673914  5.409809e+07    NaN                               NaN
#
# ...

# %%
# display title of the movie having runtime >= 180 minutes
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df[df['runtime'] >= 180]['title']
# Out:
# 25                                            Titanic
# 298                           The Wolf of Wall Street
# 329     The Lord of the Rings: The Return of the King
# 690                                    The Green Mile
# 1333                                         Magnolia
# 1818                                 Schindler's List
# Name: title, dtype: object

# %%
# in which year there was the highest average voting?
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
# change to release_date to year
df['release_date']=pd.to_datetime(df['release_date'])
df['year']=df['release_date'].dt.year
df.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
df.groupby('year')['vote_count'].mean().sort_values(ascending=False)
# Out:
# year
# 1972    5893.000000
# 1977    3565.500000
# 1984    3454.500000
# 1993    3077.333333
# 1982    2788.666667
# 2014    2373.397059
# 1979    2355.333333
# 1966    2311.000000
# 2001    2273.526316
# 1985    2235.000000
# 1995    2211.200000
# 1990    2189.000000
# 1975    2125.000000
# 1980    2068.666667
# 1989    1994.000000
# 2013    1920.963415
# 1937    1914.000000
# 1999    1907.833333
# 2015    1907.494253
# 2012    1901.824742
# 1997    1808.300000
# 1994    1764.250000
# 2016    1663.781250
# 1939    1642.000000
# 1983    1508.500000
# 2002    1494.000000
# 2003    1473.300000
# 1998    1409.250000
# 1942    1405.000000
# 1973    1269.000000
# 1992    1239.000000
# 2004    1203.318182
# 1996    1165.727273
# 1981    1135.800000
# 2010    1058.014493
# 2006    1036.102564
# 2011    1026.522581
# 2007    1013.811111
# 2008     987.660194
# 2009     979.526718
# 1962     940.000000
# 2005     886.890909
# 1940     808.000000
# 1963     760.000000
# 1986     705.000000
# ...

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='year',y='vote_count',data=df,estimator=max,color='orange')
plt.title('year vs vote_count')
plt.xlabel('year')
plt.ylabel('vote_count')
plt.xticks(rotation='vertical')
plt.show()

# %%
# in which year there was the highest average revenue?
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df.groupby('year')['revenue'].mean().sort_values(ascending=False)
# Out:
# year
# 1977    4.804183e+08
# 1993    4.229938e+08
# 1997    3.222575e+08
# 1973    3.015420e+08
# 1982    2.818933e+08
# 1942    2.674472e+08
# 1994    2.622857e+08
# 1989    2.507060e+08
# 2014    2.504389e+08
# 1983    2.499419e+08
# 1972    2.450664e+08
# 2001    2.441160e+08
# 1975    2.378415e+08
# 1990    2.208029e+08
# 2015    2.207687e+08
# 1984    2.056856e+08
# 1992    1.936524e+08
# 2016    1.928837e+08
# 2012    1.909965e+08
# 2002    1.897915e+08
# 1980    1.882145e+08
# 2013    1.881741e+08
# 1999    1.877625e+08
# 1937    1.849255e+08
# 1985    1.815585e+08
# 2003    1.743141e+08
# 2004    1.635615e+08
# 1995    1.561727e+08
# 2007    1.480107e+08
# 1996    1.469186e+08
# 1981    1.444967e+08
# 1965    1.411957e+08
# 2009    1.370055e+08
# 1979    1.349001e+08
# 2006    1.303502e+08
# 2010    1.259205e+08
# 2011    1.222309e+08
# 2008    1.159360e+08
# 2005    1.157593e+08
# 1987    1.146527e+08
# 2000    1.142369e+08
# 1998    1.135783e+08
# 1967    1.115848e+08
# ...

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='year',y='revenue',data=df,color='orange')
plt.title('highest average revenue')
plt.xlabel('year')
plt.ylabel('revenue')
plt.xticks(rotation='vertical')
plt.show()

# %%
# find the average rating for each director
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df.groupby('director')['vote_average'].mean().sort_values(ascending=False)
# Out:
# director
# Hayao Miyazaki       8.3
# Damien Chazelle      8.3
# Tony Kaye            8.2
# Lenny Abrahamson     8.1
# Sergio Leone         8.1
#                     ...
# Lawrence Kasanoff    2.3
# Ivan Kavanagh        2.0
# Bob Clark            1.9
# David Worth          0.0
# Valerie Red-Horse    0.0
# Name: vote_average, Length: 875, dtype: float64

# %%
# display top 10 lengthly movies title and runtime
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
top10_df=df.nlargest(10,'runtime')[['title','runtime']].set_index('title')
top10_df
# Out:
#                                                    runtime
# title
# The Lord of the Rings: The Return of the King        201.0
# Schindler's List                                     195.0
# Titanic                                              194.0
# The Green Mile                                       189.0
# Magnolia                                             188.0
# The Wolf of Wall Street                              180.0
# The Lord of the Rings: The Two Towers                179.0
# The Lord of the Rings: The Fellowship of the Ring    178.0
# Meet Joe Black                                       178.0
# The Godfather                                        175.0

# %%
sns.histplot(x='runtime',y=top10_df.index,data=top10_df)
plt.title('top 10 lengthly movies')
plt.xlabel('runtime')
plt.ylabel('title')
plt.show()

# %%
# display number of movies per year
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df['year'].value_counts()
# Out:
# year
# 2011    155
# 2010    138
# 2009    131
# 2008    103
# 2012     97
# 2007     90
# 2015     87
# 2013     82
# 2006     78
# 2014     68
# 2016     64
# 2005     55
# 2004     44
# 2002     35
# 2003     30
# 1999     24
# 2001     19
# 2000     19
# 1998     12
# 1996     11
# 1997     10
# 1990      5
# 1995      5
# 1981      5
# 1994      4
# 1983      4
# 1989      4
# 1993      3
# 1982      3
# 1985      3
# 1979      3
# 1980      3
# 1992      3
# 1978      3
# 1988      3
# 1984      2
# 1987      2
# 1973      2
# 1975      2
# 1971      2
# 1977      2
# 1964      2
# 1991      1
# 1986      1
# 1967      1
# 1969      1
# 1965      1
# 1972      1
# 1974      1
# 1939      1
# 1940      1
# 1963      1
# 1937      1
# 1966      1
# 1962      1
# 1970      1
# 1942      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='year',data=df)
plt.title('number of movies per year')
plt.xlabel('year')
plt.ylabel('number of movies')
plt.xticks(rotation='vertical')
plt.show()

# %%
# most popular movie title(highest revenue)
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df[df['revenue'].max()==df['revenue']]['title']
# Out:
# 0    Avatar
# Name: title, dtype: object

# %%
# display top 10 highest revenue movie titles
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
top10_df = df.nlargest(10,'revenue')[['title','revenue']].set_index('title')
top10_df
# Out:
#                                revenue
# title
# Avatar                      2787965087
# Titanic                     1845034188
# The Avengers                1519557910
# Jurassic World              1513528810
# Furious 7                   1506249360
# Avengers: Age of Ultron     1405403694
# Frozen                      1274219009
# Iron Man 3                  1215439994
# Minions                     1156730962
# Captain America: Civil War  1153304495

# %%
sns.barplot(x='revenue',y=top10_df.index,data=top10_df)
plt.title('top 10 highest revenue movie titles')
plt.xlabel('revenue')
plt.ylabel('title')
plt.show()

# %%
# find the vote average of movies year wise
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df.groupby('year')['vote_average'].mean().sort_values(ascending=False)
# Out:
# year
# 1972    8.400000
# 1966    8.100000
# 1982    7.666667
# 1975    7.650000
# 1993    7.600000
# 1978    7.433333
# 1939    7.400000
# 1995    7.380000
# 1977    7.350000
# 1990    7.340000
# 1979    7.266667
# 1994    7.250000
# 1964    7.250000
# 1940    7.200000
# 1984    7.200000
# 1986    7.100000
# 1988    7.066667
# 1997    6.980000
# 1973    6.950000
# 1989    6.900000
# 1937    6.900000
# 1962    6.900000
# 1963    6.900000
# 1985    6.900000
# 1981    6.880000
# 1942    6.800000
# 1998    6.775000
# 1983    6.725000
# 1992    6.666667
# 2001    6.652632
# 1970    6.600000
# 1999    6.583333
# 1996    6.518182
# 2003    6.510000
# 1965    6.500000
# 1967    6.500000
# 1969    6.500000
# 1987    6.450000
# 2004    6.438636
# 2007    6.394444
# 2002    6.391429
# 2014    6.391176
# 2013    6.369512
# 2006    6.365385
# 1974    6.300000
# 2005    6.267273
# 2015    6.248276
# 2009    6.219084
# 2010    6.214493
# 2012    6.169072
# 2008    6.168932
# 2011    6.137419
# ...

# %%
# does vote average the revenue?
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
sns.scatterplot(x='vote_average',y='revenue',data=df)
plt.title('vote_average,the revenue')
plt.xlabel('vote_average')
plt.ylabel('revenue')
plt.show()

# %%
# count number of action movies
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df['genres'].dtype
# Out:
# dtype('O')

# %%
len(df[df['genres'].str.contains('Action',case=False)])
# Out:
# 411

# %%
# find the unique values from genre
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director', 'year'],
#       dtype='object')

# %%
df['genres']
# Out:
# 0       Action Adventure Fantasy Science Fiction
# 1                       Adventure Fantasy Action
# 2                         Action Adventure Crime
# 3                    Action Crime Drama Thriller
# 4               Action Adventure Science Fiction
#                           ...
# 4772                         Drama Action Comedy
# 4773                                      Comedy
# 4781                              Comedy Romance
# 4791                                      Horror
# 4796              Science Fiction Drama Thriller
# Name: genres, Length: 1432, dtype: object

# %%
list1 = []
for value in df['genres']:
     list1.append(value.split(' '))

# %%
list1
# Out:
# [['Action', 'Adventure', 'Fantasy', 'Science', 'Fiction'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Science', 'Fiction'],
#  ['Fantasy', 'Action', 'Adventure'],
#  ['Animation', 'Family'],
#  ['Action', 'Adventure', 'Science', 'Fiction'],
#  ['Adventure', 'Fantasy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Action', 'Thriller', 'Crime'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Action', 'Adventure', 'Western'],
#  ['Action', 'Adventure', 'Fantasy', 'Science', 'Fiction'],
#  ['Science', 'Fiction', 'Action', 'Adventure'],
#  ['Adventure', 'Action', 'Fantasy'],
#  ['Action', 'Comedy', 'Science', 'Fiction'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure'],
#  ['Adventure', 'Fantasy'],
#  ['Adventure', 'Fantasy'],
#  ['Drama', 'Romance', 'Thriller'],
# ...

# %%
one_d = []
for item in list1:
  for item1 in item:
    one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Science',
#  'Fiction',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Science',
#  'Fiction',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Action',
#  'Adventure',
#  'Science',
#  'Fiction',
#  'Adventure',
#  'Fantasy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Action',
#  'Thriller',
#  'Crime',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Western',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Science',
#  'Fiction',
#  'Science',
#  'Fiction',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  'Science',
#  'Fiction',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Fantasy',
# ...

# %%
uni_list=[]
for item in one_d:
  if item not in uni_list:
    uni_list.append(item)

# %%
len(uni_list)
# Out:
# 22

# %%
# how many films of each genre were made?

# %%
one_d = []
for item in list1:
  for item1 in item:
    one_d.append(item1)

# %%
one_d
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Science',
#  'Fiction',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Action',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Science',
#  'Fiction',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Action',
#  'Adventure',
#  'Science',
#  'Fiction',
#  'Adventure',
#  'Fantasy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Adventure',
#  'Action',
#  'Thriller',
#  'Crime',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Western',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Science',
#  'Fiction',
#  'Science',
#  'Fiction',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  'Science',
#  'Fiction',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Adventure',
#  'Fantasy',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Action': 411,
#          'Adventure': 321,
#          'Fantasy': 168,
#          'Science': 209,
#          'Fiction': 209,
#          'Crime': 198,
#          'Drama': 607,
#          'Thriller': 399,
#          'Animation': 118,
#          'Family': 190,
#          'Western': 16,
#          'Comedy': 478,
#          'Romance': 224,
#          'Horror': 154,
#          'Mystery': 98,
#          'War': 36,
#          'History': 48,
#          'Music': 39,
#          'Documentary': 32,
#          'Foreign': 5,
#          'TV': 2,
#          'Movie': 2})

# %%
df.isnull().sum()
# Out:
# index                   0
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# director                0
# year                    0
# dtype: int64
